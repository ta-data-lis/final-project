# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import preprocessing

# %%
sample = pd.read_excel('Shopping Survey.xlsx')

# %%
sample.head()
# Out:
#                 Name  Gender  Age       Location Neighborhood level  \
# 0          Ana Frias       0   32  Lisbon center                  B
# 1          Ana Horta       0   31  Center region                  C
# 2    Beatriz Renault       0   33  Lisbon center                  B
# 3      Carlos Madriz       1   28  Lisbon center                  B
# 4  Cristina Zappullo       0   35  Lisbon center                  C
#
#    For how long do you have your loyalty card (in months)?  \
# 0                                                  0
# 1                                                  0
# 2                                                 12
# 3                                                  0
# 4                                                  0
#
#    What's your loyalty card status?  How many days do you shop per month?
# 0                                 2                                    16
# 1                                 2                                     5
# 2                                 3                                     6
# 3                                 3                                    16
# 4                                 3                                     3

# %%
le = preprocessing.LabelEncoder()
sample['Location'] = le.fit_transform(sample['Location'])

# %%
le = preprocessing.LabelEncoder()
sample['Neighborhood level'] = le.fit_transform(sample['Neighborhood level'])

# %%
sample.head()
# Out:
#                 Name  Gender  Age  Location  Neighborhood level  \
# 0          Ana Frias       0   32         1                   1
# 1          Ana Horta       0   31         0                   2
# 2    Beatriz Renault       0   33         1                   1
# 3      Carlos Madriz       1   28         1                   1
# 4  Cristina Zappullo       0   35         1                   2
#
#    For how long do you have your loyalty card (in months)?  \
# 0                                                  0
# 1                                                  0
# 2                                                 12
# 3                                                  0
# 4                                                  0
#
#    What's your loyalty card status?  How many days do you shop per month?
# 0                                 2                                    16
# 1                                 2                                     5
# 2                                 3                                     6
# 3                                 3                                    16
# 4                                 3                                     3

# %%
sample.to_csv('sample.csv')
