# %%
import GetOldTweets3 as got
import pandas as pd

# %%
#extracting tweets via getoldtweets
text_query = 'brexit'
since_date = '2016-07-13'
until_date = '2016-07-14'
#user = 'WHO'
count = 5000
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setSince(since_date).setUntil(until_date).setMaxTweets(count)
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
text_tweets = [[tweet.date, tweet.text, tweet.retweets] for tweet in tweets]

# %%
text_tweets
# Out:
# [[datetime.datetime(2016, 7, 13, 23, 59, 57, tzinfo=datetime.timezone.utc),
#   'Видео "На злобу дня - Brexit, Турция, Ресурсная Федерация" (http://youtu.be/HBPlE4-UTtQ?a) на',
#   0],
#  [datetime.datetime(2016, 7, 13, 23, 59, 55, tzinfo=datetime.timezone.utc),
#   'He will both praise her and insult her, after he explains Brexit to her. Somewhere in there he asks for money. https://twitter.com/sethbringman/status/753330780936429568',
#   0],
#  [datetime.datetime(2016, 7, 13, 23, 59, 52, tzinfo=datetime.timezone.utc),
#   "tu dis que la vente est deja actee. Tu dis aussi que les investisseurs se sont rabatus sur l'OM a cause du brexit",
#   0],
#  [datetime.datetime(2016, 7, 13, 23, 59, 50, tzinfo=datetime.timezone.utc),
#   "so she's taking Michael Gove to his word eh? No need to listen to experts? Wonder what her Brexit minister will do?",
#   0],
#  [datetime.datetime(2016, 7, 13, 23, 59, 47, tzinfo=datetime.timezone.utc),
# ...

# %%
morning_ann = pd.read_csv()
