# %%
import pickle
from NLP_Functions import *

# %%
# Testing opening the pickled Logistic Regression Trained Model
classifier_f = open('Logistic_Regression_15k.pickle', 'rb')
Logistic_Regression_classifier = pickle.load(classifier_f)
classifier_f.close()

Logistic_Regression_classifier
# Out:
# <SklearnClassifier(LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='saga', tol=0.0001, verbose=0,
#                    warm_start=False))>

# %%
# Opening the pickled most_common of the 15k sample DF
most_common_f = open('most_common_15k.pickle', 'rb')
most_common = pickle.load(most_common_f)
most_common_f.close()

#most_common

# %%
def predictor(text):
    prediction = find_features(text, most_common)
    return print('Prediction:', Logistic_Regression_classifier.classify(prediction))

predictor('This game is amazing!')
predictor('I hate this stupid bad game.')
# Out:
# Prediction: Positive
# Prediction: Negative

# %%
predictor('I hate it.') # :/
# Out:
# Prediction: Positive

# %%
sorted(most_common, key = lambda x: x[0])[1100:]
# Out:
# [('defenc', 55),
#  ('defend', 158),
#  ('defens', 203),
#  ('defiantli', 22),
#  ('defin', 149),
#  ('definetli', 19),
#  ('definit', 1129),
#  ('degrad', 18),
#  ('degre', 68),
#  ('deja', 24),
#  ('del', 143),
#  ('delay', 48),
#  ('delet', 62),
#  ('deliber', 26),
#  ('delight', 76),
#  ('deliv', 421),
#  ('deliveri', 21),
#  ('delta', 18),
#  ('delv', 25),
#  ('dem', 15),
#  ('demand', 97),
#  ('demo', 191),
#  ('demon', 214),
#  ('demonstr', 25),
#  ('den', 30),
#  ('deni', 70),
#  ('depart', 78),
#  ('departur', 21),
#  ('depend', 220),
#  ('depict', 18),
#  ('deploy', 16),
#  ('depress', 63),
#  ('depth', 538),
#  ('der', 39),
#  ('deriv', 25),
#  ('descend', 16),
#  ('descent', 28),
#  ('describ', 220),
#  ('descript', 54),
#  ('desd', 34),
#  ('desert', 92),
#  ('deserv', 617),
#  ('design', 1860),
#  ('desir', 139),
#  ('desktop', 24),
#  ('desmond', 36),
#  ('desper', 60),
#  ('despit', 490),
#  ('destin', 32),
#  ('destini', 185),
#  ('destroy', 298),
# ...
